# %%
import pandas as pd
import re
import transliterate as tr

# %%
f=open('doc.txt','r')

# %%
lis=[]
for i in f:
    if re.match('(|\s)\d{4}',i)!=None:
        print(i)
        digits=re.findall('\d+',i)
        clinic_numb=int(digits[0])
        age=digits[1]
        name=tr.translit(re.findall(r'[А-Я$а-я]+',i)[0], reversed=True)
        print(name)
    dates=re.findall(r'\d{2}.\d{2}.\d{2}', i)
    if dates!=[]:
        date=dates[0]
        types=' '.join(re.findall(r'[А-Я$а-я]+',i[0:i.rfind(':')]))
    minus_pos=[m.start() for m in re.finditer("[а-я]-\d", i)]
    for j in minus_pos:
        if i[i[0:j].rfind(' '):j+1]=='':
            param=i[0:j+1]
        else: param=i[i[0:j].rfind(' ')+1:j+1]
        if param.find(':')!=-1: param=param[param.find(':'):]
        value=i[j+2:j+i[j:].find(' ')]
        lis.append([clinic_numb,name,age,date,types,param,value])
# Out:
# 15264   Красовская Е.В.  82 года
#
# Krasovskaja
#  21332     Полякова Н.В.   48 лет
#
# Poljakova
# 4614 Горбунов В.А.   55 лет
#
# Gorbunov
# 27867    Исаева Н.М   69 лет
#
# Isaeva
# 2040 Засыпкин В.А.  62 года
#
# Zasypkin
# 11310 Оприян А.М.   60 лет
#
# Oprijan
# 20673  Ивашенко В.Г.   60 лет
#
# Ivashenko

# %%
q=pd.DataFrame(lis,columns=['clinic_numb','name','age','date','type_of_analyse','parameter','value'])

# %%
q[q['parameter']=='гемоглобин']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f3cceff1fefe> in <module>()
#       1 import transliterate as tr
# ----> 2 q[q['parameter']=='гемоглобин']
#
# NameError: name 'q' is not defined

# %%
fulldf=pd.read_csv('stroke_table.csv',sep=';', encoding='cp1251',skiprows=[1])

# %%
w=pd.merge(fulldf[['clinic_numb','adm_date']],q,left_on='clinic_numb',right_on='clinic_numb',how='inner')
w['days_after_adm']=pd.to_datetime(w['date'])-pd.to_datetime(w['adm_date'])
w['days_after_adm']=w.days_after_adm.apply(lambda x: x.days)

# %%
w.to_csv('analyses.csv', index=False)

# %%
s=pd.to_datetime('01.01.2013')-pd.to_datetime('02.01.2013')

# %%
w
# Out:
#      clinic_numb    adm_date         name age      date  \
# 0          15264  26.05.2012  Krasovskaja  82  29.05.12
# 1          15264  26.05.2012  Krasovskaja  82  29.05.12
# 2          15264  26.05.2012  Krasovskaja  82  29.05.12
# 3          15264  26.05.2012  Krasovskaja  82  29.05.12
# 4          15264  26.05.2012  Krasovskaja  82  27.05.12
# 5          15264  26.05.2012  Krasovskaja  82  27.05.12
# 6          15264  26.05.2012  Krasovskaja  82  29.05.12
# 7          15264  26.05.2012  Krasovskaja  82  29.05.12
# 8          15264  26.05.2012  Krasovskaja  82  29.05.12
# 9          15264  26.05.2012  Krasovskaja  82  29.05.12
# 10         15264  26.05.2012  Krasovskaja  82  29.05.12
# 11         15264  26.05.2012  Krasovskaja  82  28.05.12
# 12         15264  26.05.2012  Krasovskaja  82  28.05.12
# 13         15264  26.05.2012  Krasovskaja  82  28.05.12
# 14         15264  26.05.2012  Krasovskaja  82  28.05.12
# 8         Общий анализ крови отд тесты       показатель   0.93               3
# 9         Общий анализ крови отд тесты       тромбоциты    125               3
# 10        Общий анализ крови отд тесты        лейкоциты   10.1               3
# 11         Общий анализ мочи отд тесты       количество   0.08               2
# 12         Общий анализ мочи отд тесты        плотность   1030               2
# 13         Общий анализ мочи отд тесты          плоский    1-2               2
# 14         Общий анализ мочи отд тесты        лейкоциты    5-6               2
# 15         Общий анализ мочи отд тесты       эритроциты  35-40               2
# 16            Биохимия крови отд тесты              аст     22              -1
# 17            Биохимия крови отд тесты              алт      6              -1
# 18            Биохимия крови отд тесты           натрий    143              -1
# 19            Биохимия крови отд тесты            калий    4.9              -1
# 20            Биохимия крови отд тесты          хлориды    116              -1
# 21            Биохимия крови отд тесты          глюкоза    5.9              -1
# 22              Коагулограмма стандарт              мно   1.14             -62
# 23              Коагулограмма стандарт             ачтв     28             -62
# 24        Общий анализ крови отд тесты       гемоглобин   12.3              -1
# 25        Общий анализ крови отд тесты       эритроциты   3.98              -1
# 26        Общий анализ крови отд тесты       гематокрит  36.6%              -1
# 27        Общий анализ крови отд тесты       показатель   0.93              -1
# 28        Общий анализ крови отд тесты       тромбоциты    212              -1
# 29        Общий анализ крови отд тесты        лейкоциты    5.6              -1
# ..                                 ...              ...    ...             ...
# 298       Общий анализ крови отд тесты       показатель   0.87              24
# 299       Общий анализ крови отд тесты       тромбоциты    524              24
# 300       Общий анализ крови отд тесты        лейкоциты     24              24
# 301       Общий анализ крови отд тесты       гемоглобин   10.3              25
# 302       Общий анализ крови отд тесты       эритроциты   3.77              25
# 303       Общий анализ крови отд тесты       гематокрит  30.8%              25
# 304       Общий анализ крови отд тесты       показатель   0.82              25
# 305       Общий анализ крови отд тесты       тромбоциты    571              25
# 306       Общий анализ крови отд тесты       гемоглобин   10.4              28
# 307       Общий анализ крови отд тесты       эритроциты    3.8              28
# 308       Общий анализ крови отд тесты       показатель   0.82              28
# 309       Общий анализ крови отд тесты       тромбоциты    578              28
# 310       Общий анализ крови отд тесты        лейкоциты   17.7              28
# 311       Общий анализ крови отд тесты       гемоглобин   10.3              31
# 312       Общий анализ крови отд тесты       эритроциты   3.69              31
# 313       Общий анализ крови отд тесты       гематокрит  29.7%              31
# 314       Общий анализ крови отд тесты       показатель   0.84              31
# 315       Общий анализ крови отд тесты       тромбоциты    483              31
# 316       Общий анализ крови отд тесты        лейкоциты     15              31
# 317       Общий анализ крови отд тесты       эозинофилы     3%              31
# 318       Общий анализ крови отд тесты   палочкоядерные     6%              31
# 319       Общий анализ крови отд тесты  сегментоядерные    59%              31
# 320       Общий анализ крови отд тесты        лимфоциты    25%              31
# 321       Общий анализ крови отд тесты         моноциты     7%              31
# 322       Общий анализ крови отд тесты              соэ     30              31
# 323        Общий анализ мочи отд тесты       количество    0.1              21
# 324        Общий анализ мочи отд тесты        плотность   1015              21
# 325       Общий анализ крови отд тесты       гемоглобин   10.4              33
# 326       Общий анализ крови отд тесты       эритроциты    3.9              33
# 327       Общий анализ крови отд тесты        лейкоциты     12              33
#
# [328 rows x 9 columns]
